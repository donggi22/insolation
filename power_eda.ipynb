# %%
import pandas as pd

# %%
df = pd.read_csv('total_power.csv')
df
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_3852\1163825618.py:1: DtypeWarning: Columns (2,6,7,8,11,36,37,38,39,40,41,42,43,44,46,52,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('total_power.csv')
#           SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 0      329295  GJM_GSG_SGD_0001   4034               ffff
# 1      329296  GJM_GSG_SGD_0001   4034               ffff
# 2      329297  GJM_GSG_SGD_0001   4034               ffff
# 3      329298  GJM_GSG_SGD_0001   4034               ffff
# 4      329299  GJM_GSG_SGD_0001   4034               ffff
# ...       ...               ...    ...                ...
# 48437  377732  GJM_GSG_SGD_0001   4034               ffff
# 48438  377733  GJM_GSG_SGD_0001   4034               ffff
# 48439  377734  GJM_GSG_SGD_0001   4034               ffff
# 48440  377735  GJM_GSG_SGD_0001   4034               ffff
# 48441  377736  GJM_GSG_SGD_0001   4034               ffff
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48442 entries, 0 to 48441
# Data columns (total 63 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SEQ                                  48442 non-null  int64
#  1   PowerPlantID                         48442 non-null  object
#  2   Device                               48442 non-null  object
#  3   LCDBoot_ARCVersion                   48442 non-null  object
#  4   ARCStatus_PVinputConfig              48442 non-null  object
#  5   RegNum                               48442 non-null  int64
#  6   ProVer                               48442 non-null  object
#  7   MinorVer                             48442 non-null  object
#  8   SN                                   48442 non-null  object
#  9   model                                48442 non-null  object
#  10  RWRegSum                             48442 non-null  int64
# ...

# %%
plant_df = df[df['PowerPlantID'] == 'GJM_GSG_SGD_0001']
plant_df
# Out:
#           SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 0      329295  GJM_GSG_SGD_0001   4034               ffff
# 1      329296  GJM_GSG_SGD_0001   4034               ffff
# 2      329297  GJM_GSG_SGD_0001   4034               ffff
# 3      329298  GJM_GSG_SGD_0001   4034               ffff
# 4      329299  GJM_GSG_SGD_0001   4034               ffff
# ...       ...               ...    ...                ...
# 48437  377732  GJM_GSG_SGD_0001   4034               ffff
# 48438  377733  GJM_GSG_SGD_0001   4034               ffff
# 48439  377734  GJM_GSG_SGD_0001   4034               ffff
# 48440  377735  GJM_GSG_SGD_0001   4034               ffff
# 48441  377736  GJM_GSG_SGD_0001   4034               ffff
#
#       ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 0                        ffff      79   1.00     0.00  1018282223012
# 1                        ffff      79   1.00     0.00  1018282225009
# ...

# %%
plant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48408 entries, 0 to 48441
# Data columns (total 63 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SEQ                                  48408 non-null  int64
#  1   PowerPlantID                         48408 non-null  object
#  2   Device                               48408 non-null  object
#  3   LCDBoot_ARCVersion                   48408 non-null  object
#  4   ARCStatus_PVinputConfig              48408 non-null  object
#  5   RegNum                               48408 non-null  int64
#  6   ProVer                               48408 non-null  object
#  7   MinorVer                             48408 non-null  object
#  8   SN                                   48408 non-null  object
#  9   model                                48408 non-null  object
#  10  RWRegSum                             48408 non-null  int64
# ...

# %%
cols = plant_df.columns
for col in cols:
    print(plant_df[col].unique())
# Out:
# [329295 329296 329297 ... 377734 377735 377736]
# ['GJM_GSG_SGD_0001']
# ['4034' 4034]
# ['ffff']
# ['ffff']
# [79]
# ['1.00' 1.0]
# ['0.00' 0.0]
# ['1018282223012' '1018282225009' 1018282223012 1018282225009]
# ['HPC-060HL-V1-0U']
# [92]
# ['1000' 1000]
# [158096 140987 158097 ... 190976 170284 190979]
# [175.1 156.7 176.6 ... 349.4 312.4 349.5]
# [10  9  8  7  6  5  3  0  4  1]
# [ 1.   0.9  0.8 64.8  0.6 65.2  0.3  0.   0.4  0.5 65.   0.7 64.9 64.7
#  65.1 65.3 64.6  0.2]
# [57.2 51.6  0.   0.3  0.5  0.6  0.7  0.9  0.8  1.2  1.1  1.3  1.8  1.6
#   2.1  1.9  2.5  2.2  2.8  3.6  3.2  4.6  4.1  5.4  4.8  6.6  5.8  7.3
#   6.4 10.5  9.3 15.9 14.1 18.8 16.5 19.2 17.1 28.  24.8 32.2 28.7 37.9
#  34.1 40.3 36.1 45.  39.6 49.2 44.  44.8 50.5 45.3  0.4  1.5  1.4  2.
#   2.4  3.1  3.3  2.9  4.3  3.8  4.7  8.   7.1  9.6  8.5 10.3  9.2 11.7
#  10.4 19.3 16.6 19.7 17.6 19.8  3.4  3.   5.   4.4  5.2  8.3 12.2 10.8
#  14.9 13.5 16.7 20.3 18.1 31.  33.8 30.2 35.2 31.5 37.5 33.5 41.  36.4
# ...

# %%
plant_df['Warm'].value_counts()
# Out:
# Warm
# 0                   32058
# 0000000000000000    16346
# 0000000100000000        1
# 0000001000000001        1
# 1000000000000001        1
# 0100000000000000        1
# Name: count, dtype: int64

# %%
plant_df['fault4'].value_counts()
# Out:
# fault4
# 0                   32058
# 0000000000000000    16350
# Name: count, dtype: int64

# %%
plant_df[plant_df['Warm'] =='0000000100000000']
# Out:
#          SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 4800  334095  GJM_GSG_SGD_0001   4034               ffff
#
#      ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 4800                    ffff      79   1.00     0.00  1018282225009
#
#                 model  ...  BusCapacitance AcCapacitance  Pdc  MaxActivePower  \
# 4800  HPC-060HL-V1-0U  ...            1800            40  5.1              60
#
#       MaxApparentPower  DSPSecuritySpecificationVersionNumr  use_yn  crt_usr  \
# 4800                60                                    1       Y   SYSTEM
#
#                  crt_dttm  udt_dttm
# 4800  2025-10-13 14:15:03        \N
#
# [1 rows x 63 columns]

# %%
plant_df[plant_df['Warm'] =='0000001000000001']
# Out:
#          SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 4802  334097  GJM_GSG_SGD_0001   4034               ffff
#
#      ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 4802                    ffff      79   1.00     0.00  1018282225009
#
#                 model  ...  BusCapacitance AcCapacitance  Pdc  MaxActivePower  \
# 4802  HPC-060HL-V1-0U  ...            1800            40  8.8              60
#
#       MaxApparentPower  DSPSecuritySpecificationVersionNumr  use_yn  crt_usr  \
# 4802                60                                    1       Y   SYSTEM
#
#                  crt_dttm  udt_dttm
# 4802  2025-10-13 14:20:03        \N
#
# [1 rows x 63 columns]

# %%
plant_df[plant_df['Warm'] =='1000000000000001']
# Out:
#          SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 4804  334099  GJM_GSG_SGD_0001   4034               ffff
#
#      ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 4804                    ffff      79   1.00     0.00  1018282225009
#
#                 model  ...  BusCapacitance AcCapacitance  Pdc  MaxActivePower  \
# 4804  HPC-060HL-V1-0U  ...            1800            40  7.1              60
#
#       MaxApparentPower  DSPSecuritySpecificationVersionNumr  use_yn  crt_usr  \
# 4804                60                                    1       Y   SYSTEM
#
#                  crt_dttm  udt_dttm
# 4804  2025-10-13 14:25:03        \N
#
# [1 rows x 63 columns]

# %%
plant_df[plant_df['Warm'] =='0100000000000000']
# Out:
#          SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 4806  334101  GJM_GSG_SGD_0001   4034               ffff
#
#      ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 4806                    ffff      79   1.00     0.00  1018282225009
#
#                 model  ...  BusCapacitance AcCapacitance  Pdc  MaxActivePower  \
# 4806  HPC-060HL-V1-0U  ...            1800            40  9.0              60
#
#       MaxApparentPower  DSPSecuritySpecificationVersionNumr  use_yn  crt_usr  \
# 4806                60                                    1       Y   SYSTEM
#
#                  crt_dttm  udt_dttm
# 4806  2025-10-13 14:30:03        \N
#
# [1 rows x 63 columns]

# %%
plant_df[plant_df['Fault0'] =='0000000000010000']
# Out:
#          SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 4806  334101  GJM_GSG_SGD_0001   4034               ffff
#
#      ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 4806                    ffff      79   1.00     0.00  1018282225009
#
#                 model  ...  BusCapacitance AcCapacitance  Pdc  MaxActivePower  \
# 4806  HPC-060HL-V1-0U  ...            1800            40  9.0              60
#
#       MaxApparentPower  DSPSecuritySpecificationVersionNumr  use_yn  crt_usr  \
# 4806                60                                    1       Y   SYSTEM
#
#                  crt_dttm  udt_dttm
# 4806  2025-10-13 14:30:03        \N
#
# [1 rows x 63 columns]

# %%
plant_df[plant_df['DSPSecuritySpecificationVersionNumr'] =='1GJM_G']
# Out:
#          SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 3353  332648  GJM_GSG_SGD_0001   4034               ffff
# 7277  336572  GJM_GSG_SGD_0001   4034               ffff
# 7666  336961  GJM_GSG_SGD_0001   4034               ffff
#
#      ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 3353                    ffff      79   1.00     0.00  1018282223012
# 7277                    ffff      79   1.00     0.00  1018282223012
# 7666                    ffff      79   1.00     0.00  1018282223012
#
#                 model  ...  BusCapacitance AcCapacitance   Pdc  \
# 3353  HPC-060HL-V1-0U  ...            1880            40  27.1
# 7277  HPC-060HL-V1-0U  ...            1880            40  32.1
# 7666  HPC-060HL-V1-0U  ...            1880            40   3.5
#
#       MaxActivePower  MaxApparentPower  DSPSecuritySpecificationVersionNumr  \
# 3353              60                60                               1GJM_G
# ...

# %%
plant_df['Pfault']
# Out:
# 0        0000000000000000
# 1        0000000000000000
# 2        0000000000000000
# 3        0000000000000000
# 4        0000000000000000
#                ...
# 48437                   0
# 48438                   0
# 48439                   0
# 48440                   0
# 48441                   0
# Name: Pfault, Length: 48408, dtype: object

# %%
plant_df[plant_df['Pfault'] == '0000000000000000']
# Out:
#           SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 0      329295  GJM_GSG_SGD_0001   4034               ffff
# 1      329296  GJM_GSG_SGD_0001   4034               ffff
# 2      329297  GJM_GSG_SGD_0001   4034               ffff
# 3      329298  GJM_GSG_SGD_0001   4034               ffff
# 4      329299  GJM_GSG_SGD_0001   4034               ffff
# ...       ...               ...    ...                ...
# 16379  345674  GJM_GSG_SGD_0001   4034               ffff
# 16380  345675  GJM_GSG_SGD_0001   4034               ffff
# 16381  345676  GJM_GSG_SGD_0001   4034               ffff
# 16382  345677  GJM_GSG_SGD_0001   4034               ffff
# 16383  345678  GJM_GSG_SGD_0001   4034               ffff
#
#       ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 0                        ffff      79   1.00     0.00  1018282223012
# 1                        ffff      79   1.00     0.00  1018282225009
# ...

# %%
plant_df[plant_df['Device'] != 4034]
# Out:
#           SEQ      PowerPlantID Device LCDBoot_ARCVersion  \
# 0      329295  GJM_GSG_SGD_0001   4034               ffff
# 1      329296  GJM_GSG_SGD_0001   4034               ffff
# 2      329297  GJM_GSG_SGD_0001   4034               ffff
# 3      329298  GJM_GSG_SGD_0001   4034               ffff
# 4      329299  GJM_GSG_SGD_0001   4034               ffff
# ...       ...               ...    ...                ...
# 16379  345674  GJM_GSG_SGD_0001   4034               ffff
# 16380  345675  GJM_GSG_SGD_0001   4034               ffff
# 16381  345676  GJM_GSG_SGD_0001   4034               ffff
# 16382  345677  GJM_GSG_SGD_0001   4034               ffff
# 16383  345678  GJM_GSG_SGD_0001   4034               ffff
#
#       ARCStatus_PVinputConfig  RegNum ProVer MinorVer             SN  \
# 0                        ffff      79   1.00     0.00  1018282223012
# 1                        ffff      79   1.00     0.00  1018282225009
# ...

# %%
plant_df['BusCapacitance'].value_counts()
# Out:
# BusCapacitance
# 1880    44464
# 1784      288
# 1800      282
# 1807      275
# 1786      266
# 1829      171
# 1796      146
# 1799      144
# 1791      144
# 1832      144
# 1803      144
# 1845      144
# 1792      144
# 1817      142
# 1777      141
# 1795      140
# 1808      138
# 1822      138
# 1816      134
# 1810      134
# 1785      132
# 1773      132
# 1839      131
# 1761      129
# 1769      127
# 1870       34
# Name: count, dtype: int64

# %%
plant_df['AcCapacitance'].value_counts()
# Out:
# AcCapacitance
# 40    47895
# 20      513
# Name: count, dtype: int64

# %%
plant_df['Pdc'].value_counts()
# Out:
# Pdc
# 0.0     1344
# 0.8      974
# 0.9      727
# 1.0      620
# 1.1      559
#         ...
# 48.9       1
# 49.5       1
# 50.2       1
# 51.4       1
# 50.0       1
# Name: count, Length: 493, dtype: int64

# %%
plant_df['Mode'].value_counts()
# Out:
# Mode
# 1000    31176
# 1000    15888
# 2000      882
# 2000      462
# Name: count, dtype: int64

# %%
plant_df.groupby('Mode').size()
# Out:
# Mode
# 1000    31176
# 2000      882
# 1000    15888
# 2000      462
# dtype: int64

# %%
plant_df['Mode'].map(repr).value_counts()
# Out:
# Mode
# 1000      31176
# '1000'    15888
# 2000        882
# '2000'      462
# Name: count, dtype: int64
