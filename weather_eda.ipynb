# %%
import pandas as pd

# %%
df = pd.read_csv('total_weather.csv')
df
# Out:
#        weather_info_id      solarpower_sn  base_date  base_time  nx  ny lgt  \
# 0                98123           KH_WM_01   20250926       1600  59  75   0
# 1                98124       HDS_SP_E0001   20250926       1600  51  79   0
# 2                98125   YAG_HSM_SWR_0001   20250926       1600  53  65   0
# 3                98126           SB_WM_01   20250926       1600  59  74   0
# 4                98127   GJM_GSG_SGD_0001   20250926       1600  55  74   0
# ...                ...                ...        ...        ...  ..  ..  ..
# 39966           138124   NJS_ACHD_WG_0002   20260408       1000  56  71   0
# 39967           138125           KH_WM_01   20260408       1000  59  75   0
# 39968           138126           SB_WM_01   20260408       1000  59  74   0
# 39969           138127  NJS_ROK_GANA_0001   20260408       1000  57  71   0
# 39970           138128  GJM_GSG_CDAM_0001   20260408       1000  58  76   0
#
# ...

# %%
moa_df = df[df['solarpower_sn'] == 'GJM_GSG_SGD_0001']
moa_df
# Out:
#        weather_info_id     solarpower_sn  base_date  base_time  nx  ny lgt  \
# 4                98127  GJM_GSG_SGD_0001   20250926       1600  55  74   0
# 10               98133  GJM_GSG_SGD_0001   20250926       1700  55  74   0
# 21               98144  GJM_GSG_SGD_0001   20250926       1800  55  74   0
# 41               98164  GJM_GSG_SGD_0001   20251002       1800  55  74   0
# 48               98171  GJM_GSG_SGD_0001   20251002       1700  55  74  \N
# ...                ...               ...        ...        ...  ..  ..  ..
# 39925           138083  GJM_GSG_SGD_0001   20260408        600  55  74   0
# 39937           138095  GJM_GSG_SGD_0001   20260408        700  55  74   0
# 39949           138107  GJM_GSG_SGD_0001   20260408        800  55  74   0
# 39957           138115  GJM_GSG_SGD_0001   20260408        900  55  74   0
# 39962           138120  GJM_GSG_SGD_0001   20260408       1000  55  74   0
#
# ...

# %%
moa_df.to_csv('./moa_weather.csv', index=False)

# %%
moa_df = pd.read_csv('moa_weather.csv')
moa_df
# Out:
#       weather_info_id     solarpower_sn  base_date  base_time  nx  ny lgt  \
# 0               98127  GJM_GSG_SGD_0001   20250926       1600  55  74   0
# 1               98133  GJM_GSG_SGD_0001   20250926       1700  55  74   0
# 2               98144  GJM_GSG_SGD_0001   20250926       1800  55  74   0
# 3               98164  GJM_GSG_SGD_0001   20251002       1800  55  74   0
# 4               98171  GJM_GSG_SGD_0001   20251002       1700  55  74  \N
# ...               ...               ...        ...        ...  ..  ..  ..
# 3980           138083  GJM_GSG_SGD_0001   20260408        600  55  74   0
# 3981           138095  GJM_GSG_SGD_0001   20260408        700  55  74   0
# 3982           138107  GJM_GSG_SGD_0001   20260408        800  55  74   0
# 3983           138115  GJM_GSG_SGD_0001   20260408        900  55  74   0
# 3984           138120  GJM_GSG_SGD_0001   20260408       1000  55  74   0
#
#       pty     rn1  sky  ...   reh  rn1v  uuu  vvv  vec  wsd  use_yn  \
# ...

# %%
cols = moa_df.columns
for col in cols:
    print(moa_df[col].unique())
# Out:
# [ 98127  98133  98144 ... 138107 138115 138120]
# ['GJM_GSG_SGD_0001']
# [20250926 20251002 20251003 20251004 20251005 20251006 20251007 20251008
#  20251009 20251010 20251011 20251012 20251013 20251014 20251015 20251016
#  20251017 20251018 20251019 20251020 20251021 20251022 20251023 20251024
#  20251025 20251027 20251028 20251029 20251030 20251031 20251101 20251103
#  20251104 20251105 20251106 20251107 20251108 20251109 20251110 20251111
#  20251112 20251113 20251114 20251115 20251117 20251118 20251119 20251120
#  20251121 20251122 20251123 20251124 20251125 20251126 20251127 20251128
#  20251129 20251130 20251201 20251202 20251203 20251204 20251205 20251206
#  20251207 20251208 20251209 20251210 20251211 20251212 20251213 20251214
#  20251215 20251216 20251217 20251218 20251219 20251220 20251221 20251222
#  20251223 20251224 20251225 20251226 20251227 20251228 20251229 20251230
#  20251231 20260101 20260102 20260103 20260104 20260105 20260106 20260107
# ...
